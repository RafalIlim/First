# %% [markdown]
# <a href="https://colab.research.google.com/github/RafalIlim/First/blob/main/Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Template

# %%
print('hello colab')
from google.colab.patches import cv2_imshow
import cv2
cv2.__version__
# Out:
# hello colab
# '4.6.0'

# %%
img = cv2.imread(filename='view.jpg')
#img
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F3467A71B50>

# %%
img.shape
# Out:
# (480, 586, 3)

# %%
cv2.imwrite(filename='vie-copy.png', img=img)
# Out:
# True

# %%
img=cv2.imread(filename='view.jpg', flags=cv2.IMREAD_GRAYSCALE)

# %%
img
# Out:
# array([[74, 71, 79, ..., 78, 82, 81],
#        [77, 78, 76, ..., 81, 81, 79],
#        [79, 79, 75, ..., 81, 78, 78],
#        ...,
#        [41, 39, 34, ..., 45, 42, 37],
#        [37, 37, 38, ..., 37, 40, 54],
#        [39, 40, 43, ..., 50, 53, 47]], dtype=uint8)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=586x480 at 0x7F3467A630D0>

# %%
img.shape
# Out:
# (480, 586)

# %%
img1 = cv2.imread(filename='bear.jpg')
img2 = cv2.imread(filename='view.jpg')

# %%
add_img = cv2.add(src1=img1, src2=img2)
add_img.shape
# Out:
# (480, 586, 3)

# %%
cv2_imshow(add_img)
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F34669AFB50>

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F3466A052D0>

# %%
dst = cv2.addWeighted(src1=img1, alpha=0.1, src2=img2, beta=0.7, gamma=0)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F345E2759D0>
